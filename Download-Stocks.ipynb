# %% [markdown]
# # Imports

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd
from pandas_datareader import data as web # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import datetime as dt # For defining dates
import mplfinance as mpf # Matplotlib finance

import time

# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

# %% [markdown]
# # Holds Stocks Not Downloaded

# %%
stocks_not_downloaded = []

# %% [markdown]
# # Save Stock Data to CSV

# %%
def save_to_csv_from_yahoo(folder, ticker, syear, smonth, sday, eyear, emonth, eday):
    start = dt.datetime(syear, smonth, sday)
    end = dt.date(eyear, emonth, eday)
    
    try:
        print("Get Data for :", ticker)
        
        df = web.DataReader(ticker, 'yahoo', start, end)["Adj Close"]
        df.to_csv(folder + ticker + '.csv')
    except Exception as ex:
        if ticker not in stocks_not_downloaded:
            stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# # Returns a Stock DataFrame from a CSV

# %%
def get_stock_df_from_csv(folder, ticker):
    try:
        df = pd.read_csv(folder + ticker + '.csv')
    except FileNotFoundError:
        print("File Dosen't Exist")
    else:
        return df

# %% [markdown]
# # Return a Named Columns Data from a CSV

# %%
def get_column_from_csv(file, col_name):
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Dosen't Exist")
    else:
        return df[col_name]

# %% [markdown]
# # Test Receiving Stock Tickers

# %%
tickers = get_column_from_csv("./Wilshire-5000-Stocks.csv", "Ticker")
tickers
# Out:
# 0          A
# 1         AA
# 2        AAL
# 3       AAME
# 4        AAN
#         ...
# 3476    ZUMZ
# 3477     ZUO
# 3478    ZYNE
# 3479    ZYXI
# 3480    ZNGA
# Name: Ticker, Length: 3481, dtype: object

# %% [markdown]
# # Get 4 Years of Data for the All Stocks

# %%
folder = "./Stocks List/"

for x in range(3481):
    save_to_csv_from_yahoo(folder, tickers[x], 2017, 1, 1, 2021, 10, 31)
    time.sleep(1)
print("Finished")
# Out:
# Get Data for : A
# Get Data for : AA
# Get Data for : AAL
# Get Data for : AAME
# Get Data for : AAN
# Get Data for : AAOI
# Get Data for : AAON
# Get Data for : AAP
# Get Data for : AAPL
# Get Data for : AAT
# Get Data for : AAWW
# Get Data for : AXON
# Get Data for : ABBV
# Get Data for : ABC
# Get Data for : ABCB
# Get Data for : ABEO
# Get Data for : ABG
# Get Data for : ABIO
# Get Data for : ABM
# Get Data for : ABMD
# Get Data for : ABR
# Get Data for : ABT
# Get Data for : ABTX
# Get Data for : AC
# Get Data for : ACA
# Get Data for : ACAD
# Get Data for : ACBI
# Get Data for : ACC
# Get Data for : ACCO
# Get Data for : ACER
# Get Data for : ACGL
# Get Data for : ACHC
# Get Data for : ACHV
# Get Data for : ACIA
# Couldn't Get Data for : ACIA
# Get Data for : ACIW
# Get Data for : ACLS
# Get Data for : ACM
# Get Data for : ACMR
# Get Data for : ACN
# Get Data for : ACNB
# Get Data for : ACOR
# Get Data for : ACRE
# Get Data for : ACRS
# Get Data for : ACRX
# Get Data for : ACTG
# Get Data for : ACU
# Get Data for : ACY
# Get Data for : ADBE
# Get Data for : ADC
# Get Data for : ADES
# Get Data for : ADI
# Get Data for : ADM
# Couldn't Get Data for : ADM
# Get Data for : ADMA
# Couldn't Get Data for : ADMA
# Get Data for : ADMP
# Couldn't Get Data for : ADMP
# Get Data for : ADMS
# Get Data for : ADNT
# Get Data for : ADP
# Get Data for : ADRO
# Couldn't Get Data for : ADRO
# Get Data for : ADS
# Get Data for : ADSK
# Get Data for : ADSW
# Couldn't Get Data for : ADSW
# Get Data for : ADT
# Get Data for : ADTN
# Get Data for : ADUS
# Get Data for : ADVM
# Get Data for : ADXS
# Get Data for : AE
# Get Data for : AEE
# Get Data for : AEGN
# Couldn't Get Data for : AEGN
# Get Data for : AEHR
# Get Data for : AEIS
# Get Data for : AEL
# Get Data for : AEMD
# Get Data for : AEO
# Get Data for : AEP
# Get Data for : AERI
# Get Data for : AES
# Get Data for : AEY
# Get Data for : AFG
# Get Data for : AFH
# Couldn't Get Data for : AFH
# Get Data for : AFI
# Get Data for : AFIN
# Get Data for : AFL
# Get Data for : AGCO
# Get Data for : AGE
# Get Data for : AGEN
# Get Data for : AGFS
# Get Data for : AGIO
# Get Data for : AGLE
# Get Data for : AGM
# Get Data for : AGNC
# Get Data for : AGO
# Get Data for : AGR
# Get Data for : AGRX
# Get Data for : AGS
# Get Data for : AGTC
# Get Data for : AGX
# Get Data for : AGYS
# Get Data for : AHC
# Couldn't Get Data for : AHC
# Get Data for : AHH
# Get Data for : AHT
# Get Data for : AIG
# Get Data for : AIMC
# Get Data for : AIMT
# Couldn't Get Data for : AIMT
# Get Data for : AIN
# Get Data for : AINC
# Get Data for : AIR
# Get Data for : AIRG
# Get Data for : AIRI
# Get Data for : AIRT
# Get Data for : AIT
# Get Data for : AIV
# Get Data for : AIZ
# Get Data for : AJG
# Get Data for : AJRD
# Get Data for : AJX
# Get Data for : AKAM
# Get Data for : AKBA
# Get Data for : AKCA
# Couldn't Get Data for : AKCA
# Get Data for : AKER
# Couldn't Get Data for : AKER
# Get Data for : AKR
# Get Data for : AKTS
# Get Data for : AL
# Get Data for : ALB
# Get Data for : ALBO
# Get Data for : ALCO
# Get Data for : ALDX
# Get Data for : ALE
# Get Data for : ALEC
# Get Data for : ALEX
# Get Data for : ALG
# Get Data for : ALGN
# Get Data for : ALGT
# Get Data for : ALIM
# Get Data for : ALJJ
# Get Data for : ALK
# Get Data for : ALKS
# Get Data for : ALL
# Get Data for : ALLE
# Get Data for : ALLK
# Get Data for : ALLO
# Get Data for : ALLY
# Get Data for : ALNA
# Get Data for : ALNY
# Get Data for : ALOT
# Get Data for : ALPN
# Get Data for : ALRM
# Get Data for : ALSK
# Couldn't Get Data for : ALSK
# Get Data for : ALSN
# Get Data for : ALT
# Get Data for : ALTM
# Get Data for : ALTR
# Get Data for : ALV
# Get Data for : ALX
# Get Data for : ALXN
# Couldn't Get Data for : ALXN
# Get Data for : AM
# Get Data for : AMAG
# Couldn't Get Data for : AMAG
# Get Data for : AMAL
# Get Data for : AMAT
# Get Data for : AMBC
# Get Data for : AMC
# Get Data for : AMCX
# Get Data for : AMD
# Get Data for : AME
# Get Data for : AMED
# Get Data for : AMG
# Get Data for : AMGN
# Get Data for : AMH
# Get Data for : AMKR
# Get Data for : AMN
# Get Data for : AMNB
# Get Data for : AMOT
# Get Data for : AMP
# Get Data for : AMPE
# Get Data for : AMPH
# Get Data for : AMRB
# Couldn't Get Data for : AMRB
# Get Data for : AMRC
# Get Data for : AMRK
# Couldn't Get Data for : AMRK
# Get Data for : AMRS
# Couldn't Get Data for : AMRS
# Get Data for : AMRX
# Get Data for : AMS
# Get Data for : AMSC
# Get Data for : AMSF
# Get Data for : AMSWA
# Get Data for : AMT
# Get Data for : AMTD
# Couldn't Get Data for : AMTD
# Get Data for : AMTX
# Get Data for : AMWD
# Get Data for : AMZN
# Get Data for : AN
# Get Data for : ANAB
# Get Data for : ANAT
# Get Data for : ANDE
# Get Data for : ANET
# Get Data for : ANF
# Couldn't Get Data for : ANF
# Get Data for : ANGI
# Get Data for : ANGO
# Get Data for : ANH
# Couldn't Get Data for : ANH
# Get Data for : ANIK
# Get Data for : ANIP
# Get Data for : ANIX
# Couldn't Get Data for : ANIX
# Get Data for : ANSS
# Get Data for : ANTM
# Get Data for : AON
# Get Data for : AOS
# Get Data for : AOSL
# Get Data for : AP
# Get Data for : APA
# Get Data for : APAM
# Get Data for : APD
# Get Data for : APDN
# Get Data for : APEI
# Get Data for : APEN
# Get Data for : APH
# Get Data for : APLE
# Get Data for : APLS
# Get Data for : APOG
# Get Data for : APPF
# Get Data for : APPN
# Get Data for : APPS
# Get Data for : APRN
# Get Data for : APT
# Get Data for : APTS
# Get Data for : APTV
# Get Data for : APVO
# Get Data for : APYX
# Get Data for : AQB
# Get Data for : AQMS
# Get Data for : AQUA
# Get Data for : AR
# Get Data for : ARA
# Couldn't Get Data for : ARA
# Get Data for : ARAV
# Get Data for : ARAY
# Get Data for : ARC
# Get Data for : ARCB
# Get Data for : ARCH
# Get Data for : ARDX
# Get Data for : ARE
# Get Data for : ARES
# Get Data for : ARGO
# Get Data for : ARI
# Get Data for : ARKR
# Get Data for : ARL
# Get Data for : ARLO
# Get Data for : ARMK
# Get Data for : ARNA
# Get Data for : ARNC
# Get Data for : AROC
# Get Data for : AROW
# Get Data for : ARPO
# Couldn't Get Data for : ARPO
# Get Data for : ARR
# Get Data for : ARTNA
# Get Data for : ARTW
# Get Data for : ARVN
# Get Data for : ARW
# Get Data for : ARWR
# Get Data for : ASB
# Get Data for : ASFI
# Couldn't Get Data for : ASFI
# Get Data for : ASGN
# Get Data for : ASH
# Get Data for : ASIX
# Get Data for : ASMB
# Get Data for : ASNA
# Couldn't Get Data for : ASNA
# Get Data for : ASPN
# Get Data for : ASPS
# Get Data for : ASRT
# Get Data for : ASRV
# Get Data for : ASTC
# Get Data for : ASTE
# Get Data for : ASUR
# Get Data for : ASYS
# Get Data for : ATEC
# Get Data for : ATEN
# Get Data for : ATGE
# Get Data for : ATH
# Get Data for : ATHX
# Get Data for : ATI
# Get Data for : ATKR
# Get Data for : ATLC
# Get Data for : ATLO
# Get Data for : ATNI
# Get Data for : ATNM
# Get Data for : ATNX
# Get Data for : ATO
# Get Data for : ATOS
# Get Data for : ATR
# Get Data for : ATRA
# Get Data for : ATRC
# Get Data for : ATRI
# Get Data for : ATRO
# Get Data for : ATRS
# Couldn't Get Data for : ATRS
# Get Data for : ATSG
# Get Data for : ATUS
# Get Data for : ATVI
# Get Data for : AUBN
# Get Data for : AUMN
# Get Data for : AUTO
# Get Data for : AVA
# Get Data for : AVAV
# Get Data for : AVB
# Get Data for : AVD
# Get Data for : AVEO
# Get Data for : AVGO
# Get Data for : AVGR
# Get Data for : AVID
# Get Data for : AVLR
# Get Data for : AVNS
# Get Data for : AVNW
# Get Data for : AVRO
# Get Data for : AVT
# Get Data for : AVTR
# Get Data for : AVXL
# Get Data for : AVY
# Get Data for : AVYA
# Get Data for : AWI
# Get Data for : AWK
# Get Data for : AWR
# Get Data for : AWRE
# Get Data for : AWSM
# Couldn't Get Data for : AWSM
# Get Data for : AX
# Get Data for : AXAS
# Get Data for : AXDX
# Get Data for : AXE
# Couldn't Get Data for : AXE
# Get Data for : AXGN
# Get Data for : AXL
# Get Data for : AXNX
# Get Data for : AXP
# Get Data for : AXR
# Get Data for : AXS
# Get Data for : AXSM
# Get Data for : AXTA
# Get Data for : AXTI
# Get Data for : AYI
# Get Data for : AYX
# Get Data for : AZO
# Get Data for : AZPN
# Get Data for : AZZ
# Get Data for : B
# Get Data for : BA
# Get Data for : BAC
# Get Data for : BAH
# Get Data for : BANC
# Get Data for : BAND
# Get Data for : BANF
# Get Data for : BANR
# Get Data for : BASI
# Couldn't Get Data for : BASI
# Get Data for : BATRA
# Get Data for : BATRK
# Get Data for : BAX
# Get Data for : BBBY
# Get Data for : BBCP
# Get Data for : BBGI
# Get Data for : BBSI
# Get Data for : BBW
# Get Data for : BBY
# Get Data for : BC
# Get Data for : BCBP
# Get Data for : BCC
# Get Data for : BCEI
# Get Data for : BCLI
# Get Data for : BCO
# Get Data for : BCOR
# Get Data for : BCOV
# Get Data for : BCPC
# Get Data for : BCRX
# Get Data for : BDC
# Get Data for : BDGE
# Couldn't Get Data for : BDGE
# Get Data for : BDL
# Get Data for : BDN
# Get Data for : BDSI
# Get Data for : BDX
# Get Data for : BE
# Get Data for : BEAT
# Couldn't Get Data for : BEAT
# Get Data for : BECN
# Get Data for : BELFA
# Get Data for : BELFB
# Get Data for : BEN
# Get Data for : BERY
# Get Data for : BFAM
# Get Data for : BFIN
# Get Data for : BFS
# Get Data for : BFST
# Get Data for : BG
# Get Data for : BGCP
# Get Data for : BGFV
# Get Data for : BGS
# Get Data for : BGSF
# Get Data for : BH
# Get Data for : BHB
# Get Data for : BHE
# Get Data for : BHF
# Get Data for : BHLB
# Get Data for : BHR
# Get Data for : BHVN
# Get Data for : BIG
# Get Data for : BIIB
# Get Data for : BIO
# Get Data for : BIOC
# Get Data for : BIOL
# Get Data for : BJ
# Get Data for : BJRI
# Get Data for : BK
# Get Data for : BKD
# Get Data for : BKE
# Get Data for : BKH
# Get Data for : BKI
# Get Data for : BKNG
# Get Data for : BKSC
# Get Data for : BKTI
# Get Data for : BKU
# Get Data for : BL
# Get Data for : BLBD
# Get Data for : BLCM
# Get Data for : BLD
# Get Data for : BLDR
# Get Data for : BLFS
# Get Data for : BLK
# Get Data for : BLKB
# Get Data for : BLL
# Get Data for : BLMN
# Get Data for : BLUE
# Get Data for : BMCH
# Couldn't Get Data for : BMCH
# Get Data for : BMI
# Get Data for : BMRC
# Get Data for : BMRN
# Get Data for : BMTC
# Get Data for : BMY
# Get Data for : BNED
# Couldn't Get Data for : BNED
# Get Data for : BNFT
# Get Data for : BOCH
# Get Data for : BOH
# Get Data for : BOKF
# Get Data for : BOMN
# Couldn't Get Data for : BOMN
# Get Data for : BOOM
# Get Data for : BOOT
# Get Data for : BOTJ
# Get Data for : BOX
# Get Data for : BPFH
# Couldn't Get Data for : BPFH
# Get Data for : BPMC
# Get Data for : BPOP
# Get Data for : BPRN
# Get Data for : BPTH
# Get Data for : BR
# Couldn't Get Data for : BR
# Get Data for : BRC
# Get Data for : BREW
# Couldn't Get Data for : BREW
# Get Data for : BRG
# Get Data for : BRID
# Couldn't Get Data for : BRID
# Get Data for : BRKL
# Get Data for : BRKR
# Get Data for : BRKS
# Get Data for : BRN
# Get Data for : BRO
# Get Data for : BRT
# Get Data for : BRX
# Couldn't Get Data for : BRX
# Get Data for : BRY
# Get Data for : BSET
# Couldn't Get Data for : BSET
# Get Data for : BSGM
# Get Data for : BSQR
# Get Data for : BSRR
# Get Data for : BSTC
# Couldn't Get Data for : BSTC
# Get Data for : BSX
# Get Data for : BTN
# Get Data for : BTU
# Get Data for : BURL
# Get Data for : BUSE
# Get Data for : BV
# Get Data for : BW
# Get Data for : BWA
# Get Data for : BWEN
# Get Data for : BWFG
# Get Data for : BWXT
# Get Data for : BXC
# Get Data for : BXMT
# Couldn't Get Data for : BXMT
# Get Data for : BXP
# Get Data for : BXS
# Couldn't Get Data for : BXS
# Get Data for : BY
# Get Data for : BYD
# Get Data for : BYFC
# Get Data for : BYND
# Get Data for : BZH
# Get Data for : C
# Get Data for : CABO
# Get Data for : CAC
# Get Data for : CACC
# Get Data for : CACI
# Get Data for : CADE
# Get Data for : CAG
# Get Data for : CAH
# Get Data for : CAI
# Get Data for : CAKE
# Get Data for : CAL
# Get Data for : CALA
# Get Data for : CALM
# Get Data for : CALX
# Get Data for : CAMP
# Get Data for : CAPR
# Get Data for : CAR
# Get Data for : CARA
# Get Data for : CARG
# Get Data for : CARS
# Get Data for : CASA
# Get Data for : CASH
# Get Data for : CASI
# Get Data for : CASS
# Get Data for : CASY
# Get Data for : CAT
# Get Data for : CATB
# Couldn't Get Data for : CATB
# Get Data for : CATC
# Get Data for : CATM
# Couldn't Get Data for : CATM
# Get Data for : CATO
# Get Data for : CATS
# Couldn't Get Data for : CATS
# Get Data for : CATY
# Get Data for : CB
# Get Data for : CBAN
# Get Data for : CBAY
# Get Data for : CBB
# Get Data for : CBFV
# Get Data for : CBIO
# Get Data for : CBLI
# Get Data for : CBMG
# Couldn't Get Data for : CBMG
# Get Data for : CBOE
# Get Data for : CBRE
# Get Data for : CBRL
# Couldn't Get Data for : CBRL
# Get Data for : CBSH
# Get Data for : CBT
# Get Data for : CBTX
# Get Data for : CBU
# Get Data for : CBZ
# Get Data for : CC
# Get Data for : CCBG
# Get Data for : CCF
# Couldn't Get Data for : CCF
# Get Data for : CCI
# Get Data for : CCK
# Get Data for : CCL
# Get Data for : CCMP
# Get Data for : CCNE
# Get Data for : CCO
# Get Data for : CCOI
# Get Data for : CCRN
# Get Data for : CCS
# Get Data for : CCXI
# Get Data for : CDAY
# Get Data for : CDE
# Get Data for : CDEV
# Get Data for : CDK
# Get Data for : CDLX
# Get Data for : CDMO
# Get Data for : CDNA
# Get Data for : CDNS
# Get Data for : CDR
# Get Data for : CDTX
# Get Data for : CDW
# Get Data for : CDXC
# Get Data for : CDXS
# Get Data for : CDZI
# Get Data for : CE
# Get Data for : CECE
# Get Data for : CEI
# Get Data for : CEIX
# Get Data for : CELC
# Get Data for : CELH
# Get Data for : CEMI
# Get Data for : CENT
# Get Data for : CENTA
# Get Data for : CENX
# Get Data for : CERC
# Couldn't Get Data for : CERC
# Get Data for : CERN
# Get Data for : CERS
# Get Data for : CETV
# Couldn't Get Data for : CETV
# Get Data for : CETX
# Get Data for : CEVA
# Get Data for : CF
# Get Data for : CFBK
# Get Data for : CFFI
# Get Data for : CFFN
# Get Data for : CFG
# Get Data for : CFMS
# Get Data for : CFR
# Get Data for : CFX
# Get Data for : CGIX
# Couldn't Get Data for : CGIX
# Get Data for : CGNX
# Get Data for : CHAP
# Couldn't Get Data for : CHAP
# Get Data for : CHCI
# Get Data for : CHCO
# Get Data for : CHCT
# Get Data for : CHD
# Get Data for : CHDN
# Get Data for : CHE
# Get Data for : CHEF
# Get Data for : CHGG
# Get Data for : CHH
# Get Data for : CHK
# Get Data for : CHMA
# Get Data for : CHMG
# Get Data for : CHMI
# Get Data for : CHRS
# Get Data for : CHRW
# Get Data for : CHS
# Get Data for : CHTR
# Get Data for : CHUY
# Get Data for : CI
# Get Data for : CIA
# Get Data for : CIDM
# Get Data for : CIEN
# Get Data for : CIM
# Get Data for : CINF
# Get Data for : CIO
# Get Data for : CIR
# Get Data for : CIT
# Get Data for : CIVB
# Get Data for : CIX
# Get Data for : CIZN
# Get Data for : CKH
# Couldn't Get Data for : CKH
# Get Data for : CKX
# Get Data for : CL
# Get Data for : CLAR
# Get Data for : CLB
# Get Data for : CLBS
# Get Data for : CLCT
# Couldn't Get Data for : CLCT
# Get Data for : CLDR
# Get Data for : CLDT
# Get Data for : CLDX
# Get Data for : CLF
# Get Data for : CLFD
# Get Data for : CLGX
# Couldn't Get Data for : CLGX
# Get Data for : CLH
# Get Data for : CLI
# Get Data for : CLIR
# Get Data for : CLNC
# Couldn't Get Data for : CLNC
# Get Data for : CLNE
# Get Data for : CLNY
# Couldn't Get Data for : CLNY
# Get Data for : CLPR
# Get Data for : CLR
# Get Data for : CLRB
# Get Data for : CLRO
# Get Data for : CLSN
# Get Data for : CLUB
# Couldn't Get Data for : CLUB
# Get Data for : CLVS
# Couldn't Get Data for : CLVS
# Get Data for : CLW
# Get Data for : CLX
# Get Data for : CLXT
# Couldn't Get Data for : CLXT
# Get Data for : CMA
# Couldn't Get Data for : CMA
# Get Data for : CMC
# Get Data for : CMCO
# Get Data for : CMCSA
# Get Data for : CMCT
# Get Data for : CMD
# Couldn't Get Data for : CMD
# Get Data for : CME
# Get Data for : CMG
# Get Data for : CMI
# Get Data for : CMO
# Couldn't Get Data for : CMO
# Get Data for : CMP
# Get Data for : CMRX
# Couldn't Get Data for : CMRX
# Get Data for : CMS
# Get Data for : CMT
# Get Data for : CMTL
# Get Data for : CNA
# Get Data for : CNBKA
# Couldn't Get Data for : CNBKA
# Get Data for : CNC
# Get Data for : CNCE
# Get Data for : CNDT
# Get Data for : CNFR
# Get Data for : CNK
# Get Data for : CNMD
# Get Data for : CNNE
# Get Data for : CNO
# Get Data for : CNOB
# Get Data for : CNP
# Get Data for : CNS
# Get Data for : CNSL
# Get Data for : CNTY
# Get Data for : CNX
# Get Data for : CNXN
# Get Data for : CODA
# Get Data for : COF
# Get Data for : COG
# Couldn't Get Data for : COG
# Get Data for : COHN
# Get Data for : COHR
# Get Data for : COHU
# Get Data for : COKE
# Get Data for : COLB
# Get Data for : COLD
# Get Data for : COLL
# Get Data for : COLM
# Get Data for : COMM
# Get Data for : CONE
# Get Data for : CONN
# Get Data for : COO
# Get Data for : COOP
# Get Data for : COP
# Get Data for : COR
# Get Data for : CORE
# Get Data for : CORR
# Get Data for : CORT
# Get Data for : COST
# Get Data for : COTY
# Get Data for : COUP
# Get Data for : COWN
# Get Data for : CPB
# Get Data for : CPE
# Get Data for : CPF
# Get Data for : CPHC
# Get Data for : CPIX
# Get Data for : CPK
# Get Data for : CPLG
# Get Data for : CPRI
# Get Data for : CPRT
# Get Data for : CPRX
# Get Data for : CPS
# Get Data for : CPSH
# Get Data for : CPSI
# Get Data for : CPSS
# Get Data for : CPST
# Couldn't Get Data for : CPST
# Get Data for : CPT
# Get Data for : CR
# Get Data for : CRAI
# Get Data for : CRBP
# Get Data for : CRC
# Get Data for : CREE
# Get Data for : CRI
# Get Data for : CRIS
# Get Data for : CRK
# Get Data for : CRL
# Get Data for : CRM
# Get Data for : CRMD
# Get Data for : CRMT
# Get Data for : CRNX
# Get Data for : CROX
# Get Data for : CRS
# Get Data for : CRTX
# Get Data for : CRUS
# Get Data for : CRVL
# Get Data for : CRVS
# Get Data for : CRWS
# Get Data for : CRY
# Get Data for : CSCO
# Get Data for : CSGP
# Get Data for : CSGS
# Get Data for : CSII
# Get Data for : CSL
# Get Data for : CSLT
# Get Data for : CSOD
# Couldn't Get Data for : CSOD
# Get Data for : CSPI
# Get Data for : CSTR
# Get Data for : CSU
# Get Data for : CSV
# Get Data for : CSWI
# Get Data for : CSX
# Get Data for : CTAS
# Get Data for : CTB
# Get Data for : CTBI
# Get Data for : CTG
# Get Data for : CTHR
# Get Data for : CTIB
# Get Data for : CTIC
# Get Data for : CTL
# Couldn't Get Data for : CTL
# Get Data for : CTLT
# Get Data for : CTMX
# Get Data for : CTO
# Get Data for : CTRE
# Get Data for : CTRN
# Get Data for : CTS
# Get Data for : CTSH
# Get Data for : CTSO
# Get Data for : CTT
# Get Data for : CTXS
# Get Data for : CUB
# Couldn't Get Data for : CUB
# Get Data for : CUBE
# Get Data for : CUBI
# Get Data for : CUE
# Get Data for : CULP
# Get Data for : CURO
# Get Data for : CUTR
# Get Data for : CUZ
# Get Data for : CVA
# Get Data for : CVBF
# Get Data for : CVCO
# Get Data for : CVCY
# Get Data for : CVGI
# Get Data for : CVGW
# Get Data for : CVI
# Get Data for : CVIA
# Couldn't Get Data for : CVIA
# Get Data for : CVLT
# Get Data for : CVLY
# Get Data for : CVM
# Get Data for : CVNA
# Get Data for : CVR
# Get Data for : CVS
# Get Data for : CVTI
# Couldn't Get Data for : CVTI
# Get Data for : CVU
# Get Data for : CVV
# Get Data for : CVX
# Get Data for : CW
# Get Data for : CWBC
# Get Data for : CWBR
# Get Data for : CWEN
# Get Data for : CWH
# Get Data for : CWST
# Get Data for : CWT
# Get Data for : CXO
# Couldn't Get Data for : CXO
# Get Data for : CXP
# Get Data for : CXW
# Get Data for : CYAN
# Get Data for : CYBE
# Get Data for : CYCC
# Get Data for : CYH
# Get Data for : CYRX
# Get Data for : CYTK
# Get Data for : CYTR
# Get Data for : CZNC
# Get Data for : CZR
# Get Data for : CZWI
# Get Data for : D
# Get Data for : DAIO
# Get Data for : DAKT
# Get Data for : DAL
# Get Data for : DAN
# Get Data for : DAR
# Get Data for : DARE
# Get Data for : DBD
# Get Data for : DBI
# Get Data for : DBX
# Get Data for : DCI
# Get Data for : DCO
# Get Data for : DCOM
# Get Data for : DCPH
# Get Data for : DD
# Get Data for : DDD
# Couldn't Get Data for : DDD
# Get Data for : DDS
# Couldn't Get Data for : DDS
# Get Data for : DE
# Couldn't Get Data for : DE
# Get Data for : DEA
# Couldn't Get Data for : DEA
# Get Data for : DECK
# Couldn't Get Data for : DECK
# Get Data for : DEI
# Couldn't Get Data for : DEI
# Get Data for : DELL
# Couldn't Get Data for : DELL
# Get Data for : DENN
# Couldn't Get Data for : DENN
# Get Data for : DFIN
# Couldn't Get Data for : DFIN
# Get Data for : DFS
# Couldn't Get Data for : DFS
# Get Data for : DG
# Couldn't Get Data for : DG
# Get Data for : DGICA
# Couldn't Get Data for : DGICA
# Get Data for : DGII
# Couldn't Get Data for : DGII
# Get Data for : DGLY
# Couldn't Get Data for : DGLY
# Get Data for : DGX
# Couldn't Get Data for : DGX
# Get Data for : DHI
# Couldn't Get Data for : DHI
# Get Data for : DHIL
# Couldn't Get Data for : DHIL
# Get Data for : DHR
# Couldn't Get Data for : DHR
# Get Data for : DHX
# Couldn't Get Data for : DHX
# Get Data for : DIN
# Couldn't Get Data for : DIN
# Get Data for : DIOD
# Couldn't Get Data for : DIOD
# Get Data for : DIS
# Couldn't Get Data for : DIS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2132/2641106735.py in <module>
#       3 for x in range(3481):
#       4     save_to_csv_from_yahoo(folder, tickers[x], 2017, 1, 1, 2021, 10, 31)
# ----> 5     time.sleep(1)
#       6 print("Finished")
#
# KeyboardInterrupt:

# %% [markdown]
# # Download Stocks Not Downloaded

# %%
# for x in stocks_not_downloaded:
#     save_to_csv_from_yahoo(folder, tickers[x], 2017, 1, 1, 2021, 8, 19)
# print("Finished")
